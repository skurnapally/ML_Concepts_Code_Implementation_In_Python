# %%
from google.colab import drive # to use goolge drive as disk

# %%
drive.mount('/content/gdrive/') # mounting gdrive
# Out:
# Mounted at /content/gdrive/

# %%
# %cd /content/gdrive/MyDrive/Web_API/Speech-to-text
# !ls
# Out:
# /content/gdrive/MyDrive/Web_API/Speech-to-text
# GCP_speech_to_text_APIs.ipynb  parts		 speechtextcredentals.json
# genevieve.wav		       requirements.txt

# %% [markdown]
# # Preparing environment for this speech to text api
#
# - Create an environment with python3

# %%
# !cat requirements.txt # libraries required
# Out:
# google-api-python-client==1.6.4
# httplib2==0.10.3
# oauth2client==4.1.2
# pyasn1==0.4.2
# pyasn1-modules==0.2.1
# rsa==3.4.2
# six==1.12.0
# SpeechRecognition==3.8.1
# tqdm==4.19.5
# uritemplate==3.0.0

# %%
# !pip install -r requirements.txt # installing libraries as needed.
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting google-api-python-client==1.6.4
#   Downloading google_api_python_client-1.6.4-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 978 kB/s
# Collecting httplib2==0.10.3
#   Downloading httplib2-0.10.3.tar.gz (204 kB)
#      |████████████████████████████████| 204 kB 3.9 MB/s
# Collecting oauth2client==4.1.2
#   Downloading oauth2client-4.1.2-py2.py3-none-any.whl (99 kB)
#      |████████████████████████████████| 99 kB 8.1 MB/s
# Collecting pyasn1==0.4.2
#   Downloading pyasn1-0.4.2-py2.py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 8.6 MB/s
# Collecting pyasn1-modules==0.2.1
#   Downloading pyasn1_modules-0.2.1-py2.py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 6.8 MB/s
# Collecting rsa==3.4.2
#   Downloading rsa-3.4.2-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 1.7 MB/s
# Collecting six==1.12.0
#   Downloading six-1.12.0-py2.py3-none-any.whl (10 kB)
# Collecting SpeechRecognition==3.8.1
#   Downloading SpeechRecognition-3.8.1-py2.py3-none-any.whl (32.8 MB)
#      |████████████████████████████████| 32.8 MB 1.4 MB/s
# Collecting tqdm==4.19.5
#   Downloading tqdm-4.19.5-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 115 kB/s
# Collecting uritemplate==3.0.0
#   Downloading uritemplate-3.0.0-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: httplib2
#   Building wheel for httplib2 (setup.py) ... done
#   Created wheel for httplib2: filename=httplib2-0.10.3-py3-none-any.whl size=83988 sha256=ce8af08a0f3d290de0e26b0046a077b7a77ff4c627e0843a099bccffe233e5f2
#   Stored in directory: /root/.cache/pip/wheels/66/4a/d3/bcc7821f2c675e9e22669ad50027cf72f837309f1f45b6b37c
# Successfully built httplib2
# Installing collected packages: pyasn1, six, rsa, pyasn1-modules, httplib2, uritemplate, oauth2client, tqdm, SpeechRecognition, google-api-python-client
#   Attempting uninstall: pyasn1
#     Found existing installation: pyasn1 0.4.8
#     Uninstalling pyasn1-0.4.8:
#       Successfully uninstalled pyasn1-0.4.8
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: pyasn1-modules
#     Found existing installation: pyasn1-modules 0.2.8
#     Uninstalling pyasn1-modules-0.2.8:
#       Successfully uninstalled pyasn1-modules-0.2.8
#   Attempting uninstall: httplib2
#     Found existing installation: httplib2 0.17.4
#     Uninstalling httplib2-0.17.4:
#       Successfully uninstalled httplib2-0.17.4
#   Attempting uninstall: uritemplate
#     Found existing installation: uritemplate 3.0.1
#     Uninstalling uritemplate-3.0.1:
#       Successfully uninstalled uritemplate-3.0.1
#   Attempting uninstall: oauth2client
#     Found existing installation: oauth2client 4.1.3
#     Uninstalling oauth2client-4.1.3:
#       Successfully uninstalled oauth2client-4.1.3
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.0
#     Uninstalling tqdm-4.64.0:
#       Successfully uninstalled tqdm-4.64.0
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 1.12.11
#     Uninstalling google-api-python-client-1.12.11:
#       Successfully uninstalled google-api-python-client-1.12.11
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# spacy 3.4.1 requires tqdm<5.0.0,>=4.38.0, but you have tqdm 4.19.5 which is incompatible.
# prophet 1.1 requires tqdm>=4.36.1, but you have tqdm 4.19.5 which is incompatible.
# panel 0.12.1 requires tqdm>=4.48.0, but you have tqdm 4.19.5 which is incompatible.
# google-api-core 1.31.6 requires six>=1.13.0, but you have six 1.12.0 which is incompatible.
# firebase-admin 4.4.0 requires google-api-python-client>=1.7.8, but you have google-api-python-client 1.6.4 which is incompatible.
# earthengine-api 0.1.322 requires google-api-python-client<2,>=1.12.1, but you have google-api-python-client 1.6.4 which is incompatible.
# Successfully installed SpeechRecognition-3.8.1 google-api-python-client-1.6.4 httplib2-0.10.3 oauth2client-4.1.2 pyasn1-0.4.2 pyasn1-modules-0.2.1 rsa-3.4.2 six-1.12.0 tqdm-4.19.5 uritemplate-3.0.0

# %% [markdown]
# - Divide the source into multiple parts
#
# ```ffmpeg -i genevieve.wav -f segment -segment_time 30 -c copy parts/out%09d.wav```

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/Web_API/Speech-to-text

# %% [markdown]
# # English Recognition

# %%
# !ffmpeg -i english.wav -f segment -segment_time 30 -c copy parts/out%09d.wav
# Out:
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, wav, from 'english.wav':
#   Duration: 00:01:10.33, bitrate: 768 kb/s
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, mono, s16, 768 kb/s
# [segment @ 0x55afa41e4c00] Opening 'parts/out000000000.wav' for writing
# Output #0, segment, to 'parts/out%09d.wav':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, mono, s16, 768 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# [segment @ 0x55afa41e4c00] Opening 'parts/out000000001.wav' for writing
# [segment @ 0x55afa41e4c00] Opening 'parts/out000000002.wav' for writing
# size=N/A time=00:01:10.31 bitrate=N/A speed= 689x
# video:0kB audio:6594kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# from SpeechRecognition package, import speech_recognition module
# https://github.com/Uberi/speech_recognition#readme
import speech_recognition as sr
sr
# Out:
# <module 'speech_recognition' from '/usr/local/lib/python3.7/dist-packages/speech_recognition/__init__.py'>

# %%
import os
from tqdm import tqdm

from multiprocessing.dummy import Pool
pool = Pool(8) # Number of concurrent threads

# %%
pool

# %% [markdown]
# - Read the file contents of api-key.json file

# %%
with open("api-key.json") as f:
    GOOGLE_CLOUD_SPEECH_CREDENTIALS = f.read()

# %%
GOOGLE_CLOUD_SPEECH_CREDENTIALS[:10]+'...."' # cannot show you my key, sorry!
# Out:
# '{\n  "type"...."'

# %%
# get the recogniser from the speech_recognition api
r = sr.Recognizer()
r

# %%
# get the list of all the files that we want to convert
files = sorted(os.listdir('parts/'))
files
# Out:
# ['out000000000.wav', 'out000000001.wav', 'out000000002.wav']

# %% [markdown]
# - Fucntion to convert the audio to text.

# %%
name = 'parts/'+files[0]
from IPython.display import Audio
Audio(name)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Load audio file
with sr.AudioFile(name) as source:
    audio = r.record(source)
audio

# %%
# Transcribe audio file
text = r.recognize_google_cloud(
    audio,
    credentials_json=GOOGLE_CLOUD_SPEECH_CREDENTIALS
    )
text
# Out:
# 'this Dynamic Workshop aims to provide up-to-date information on pharmacological approaches, issues, and treatment in the geriatric population to assist in preventing medication related problems, appropriately and effectively managing medications and compliance. The concept of polypharmacy parentheses taking multiple types of drugs parentheses will also be discussed, as though '

# %%
def transcribe(data):
    idx, file = data
    name = "parts/" + file
    print(name + " started")
    # Load audio file
    with sr.AudioFile(name) as source:
        audio = r.record(source)
    # Transcribe audio file
    text = r.recognize_google_cloud(audio, credentials_json=GOOGLE_CLOUD_SPEECH_CREDENTIALS)
    print(name + " done")
    return {
        "idx": idx,
        "text": text
    }

# %%
# running them in parallel to make it faster
all_text = pool.map(transcribe, enumerate(files))
pool.close()
pool.join()
# Out:
# parts/out000000000.wav startedparts/out000000001.wav started
#
# parts/out000000002.wav started
# parts/out000000002.wav done
# parts/out000000001.wav done
# parts/out000000000.wav done

# %%
all_text
# Out:
# [{'idx': 0,
#   'text': 'this Dynamic Workshop aims to provide up-to-date information on pharmacological approaches, issues, and treatment in the geriatric population to assist in preventing medication related problems, appropriately and effectively managing medications and compliance. The concept of polypharmacy parentheses taking multiple types of drugs parentheses will also be discussed, as though '},
#  {'idx': 1,
#   'text': 'is a common issue that can impact adverse side effects in the geriatric population. Participants will leave with the knowledge and considerations of common drug interactions and how to minimize the effects that limit function. Summit professional education is approved provider of continuing education. This course is offered for 6. '},
#  {'idx': 2,
#   'text': '. discourse contains a Content classified under the both the domain of occupational therapy and professional issues. '}]

# %% [markdown]
# # Hindi recognition

# %%
# !ffmpeg -i hindi.wav -f segment -segment_time 30 -c copy partshindi/out%09d.wav
# Out:
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Guessed Channel Layout for Input Stream #0.0 : stereo
# Input #0, wav, from 'hindi.wav':
#   Metadata:
#     encoder         : Lavf59.27.100
#   Duration: 00:01:40.37, bitrate: 1536 kb/s
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, stereo, s16, 1536 kb/s
# [segment @ 0x5588f3ef6c00] Opening 'partshindi/out000000000.wav' for writing
# Output #0, segment, to 'partshindi/out%09d.wav':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, stereo, s16, 1536 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# [segment @ 0x5588f3ef6c00] Opening 'partshindi/out000000001.wav' for writing
# [segment @ 0x5588f3ef6c00] Opening 'partshindi/out000000002.wav' for writing
# [segment @ 0x5588f3ef6c00] Opening 'partshindi/out000000003.wav' for writing
# size=N/A time=00:01:40.35 bitrate=N/A speed= 597x
# video:0kB audio:18819kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# get the list of all the files that we want to convert
files_hindi = sorted(os.listdir('partshindi/'))
files
# Out:
# ['out000000000.wav', 'out000000001.wav', 'out000000002.wav']

# %%
name = 'partshindi/'+files_hindi[0]
from IPython.display import Audio
Audio(name)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
def transcribe(data):
    idx, file = data
    name = "partshindi/" + file
    print(name + " started")
    # Load audio file
    with sr.AudioFile(name) as source:
        audio = r.record(source)
    # Transcribe audio file
    text = r.recognize_google_cloud(audio, credentials_json=GOOGLE_CLOUD_SPEECH_CREDENTIALS)
    print(name + " done")
    return {
        "idx": idx,
        "text": text
    }

# %%
# running them in parallel to make it faster
pool = Pool(8) # Number of concurrent threads
all_text = pool.map(transcribe, enumerate(files_hindi))
pool.close()
pool.join()
# Out:
# partshindi/out000000000.wav started
# partshindi/out000000001.wav started
# partshindi/out000000002.wav started
# partshindi/out000000000.wav done
# partshindi/out000000002.wav done
# partshindi/out000000001.wav done

# %%
all_text
# Out:
# [{'idx': 0,
#   'text': 'Google Plano I love you I love you I love you very very much '},
#  {'idx': 1,
#   'text': 'I love you and mount pocket blanket better Nana Banana cartoon alcohol bottle pinata '},
#  {'idx': 2, 'text': 'Marion Kentucky take me to dental clinic video '}]

# %% [markdown]
# # Telugu Recognition

# %%
# !ffmpeg -i telugu.wav -f segment -segment_time 30 -c copy partstelugu/out%09d.wav
# Out:
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Guessed Channel Layout for Input Stream #0.0 : stereo
# Input #0, wav, from 'telugu.wav':
#   Metadata:
#     encoder         : Lavf59.27.100
#   Duration: 00:01:24.29, bitrate: 1536 kb/s
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, stereo, s16, 1536 kb/s
# [segment @ 0x563f68148c00] Opening 'partstelugu/out000000000.wav' for writing
# Output #0, segment, to 'partstelugu/out%09d.wav':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, stereo, s16, 1536 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# [segment @ 0x563f68148c00] Opening 'partstelugu/out000000001.wav' for writing
# [segment @ 0x563f68148c00] Opening 'partstelugu/out000000002.wav' for writing
# size=N/A time=00:01:24.28 bitrate=N/A speed= 681x
# video:0kB audio:15804kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# get the list of all the files that we want to convert
files_telugu= sorted(os.listdir('partstelugu/'))
files
# Out:
# ['out000000000.wav', 'out000000001.wav', 'out000000002.wav']

# %%
name = 'partstelugu/'+files_telugu[0]
from IPython.display import Audio
Audio(name)

# %%
def transcribe(data):
    idx, file = data
    name = "partstelugu/" + file
    print(name + " started")
    # Load audio file
    with sr.AudioFile(name) as source:
        audio = r.record(source)
    # Transcribe audio file
    text = r.recognize_google_cloud(audio, credentials_json=GOOGLE_CLOUD_SPEECH_CREDENTIALS)
    print(name + " done")
    return {
        "idx": idx,
        "text": text
    }

# %%
# running them in parallel to make it faster
pool = Pool(8) # Number of concurrent threads
all_text = pool.map(transcribe, enumerate(files_telugu))
pool.close()
pool.join()
all_text
# Out:
# partstelugu/out000000000.wav startedpartstelugu/out000000001.wav started
# partstelugu/out000000002.wav started
#
# partstelugu/out000000002.wav done
# partstelugu/out000000000.wav done
# partstelugu/out000000001.wav done
# [{'idx': 0,
#   'text': 'give me tomorrow Mutant Ninja Turtle Mera Dil badal De naat '},
#  {'idx': 1,
#   'text': 'mitigated boots Google since I smoked a real name just like this what are not same '},
#  {'idx': 2,
#   'text': "Manisha margosa members volunteer team on Trump I don't nobody know your tongue "}]

# %% [markdown]
# ## Looks like API is woring fine for english but not good for other languages.
